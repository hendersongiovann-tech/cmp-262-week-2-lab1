# %%
name = Giovannie Henderson
major = Information Technology
favoritenumber = 87
reason = Coding




print(name)
print(major)
print(favoritenumber)
print(reason)
# Out:
# Giovannie Henderson
# Information Technology
# 87
# coding

# %%
name = input("Please Enter Your Name")
age = input("Enter your Age")
programming_language = input("What is Your Favorite Programming Languge")

print("Thanks for the Information Provided Here are your Answers")
print(name)
print(age)
print(programming_language)
# Out:
# Thanks for the INformation Provided Here are your Answers
# Amjed
# 13
# Python

# %%
num1 = int(input("PLaese Enter First Number"))
num2 = int(input("please Enter Second Number"))
num3 = int(input("Please Enter Third Number"))

sum = num1 + num2 + num3 
average = sum / 3
largest_value = max(num1, num2, num3)
smallest_value = min(num1, num2, num3)

print("Sum", sum)
print("Average", average)
print("Larget Value", largest_value)
print("Samllest Value", smallest_value)
# Out:
# Sum 45
# Average 15.0
# Larget Value 20
# Samllest Value 10

# %%
grade = int(input("Please enter a numeric Garde (0-100)"))

if grade >= 90:
    print("A")
elif grade >= 80:
    print("B")
elif grade >= 70:
    print("C")
elif grade >= 60: 
    print("D'")
else: 
    print("F")
# Out:
# F
